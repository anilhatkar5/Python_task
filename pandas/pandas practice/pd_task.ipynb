# %%
import pandas as pd
import numpy as np

# %%
customer = pd.read_csv('E:/Data Analytics/Python/python practice/pandas/pandas practice/Customer.csv',index_col=0, header=0)

# %%
customer
# Out:
#                  Customer Name      Segment  Age        Country  \
# Customer ID
# CG-12520           Claire Gute     Consumer   67  United States
# DV-13045       Darrin Van Huff    Corporate   31  United States
# SO-20335        Sean O'Donnell     Consumer   65  United States
# BH-11710       Brosina Hoffman     Consumer   20  United States
# AA-10480          Andrew Allen     Consumer   50  United States
# ...                        ...          ...  ...            ...
# CJ-11875          Carl Jackson    Corporate   64  United States
# RS-19870            Roy Skaria  Home Office   39  United States
# SC-20845            Sung Chung     Consumer   69  United States
# RE-19405       Ricardo Emerson     Consumer   35  United States
# SM-20905     Susan MacKendrick     Consumer   46  United States
#
#                           City           State  Postal Code   Region
# Customer ID
# CG-12520             Henderson        Kentucky        42420    South
# ...

# %%
customer.iloc[0:10]
# Out:
#                   Customer Name      Segment  Age        Country  \
# Customer ID
# CG-12520            Claire Gute     Consumer   67  United States
# DV-13045        Darrin Van Huff    Corporate   31  United States
# SO-20335         Sean O'Donnell     Consumer   65  United States
# BH-11710        Brosina Hoffman     Consumer   20  United States
# AA-10480           Andrew Allen     Consumer   50  United States
# IM-15070           Irene Maddox     Consumer   66  United States
# HP-14815          Harold Pawlan  Home Office   20  United States
# PK-19075              Pete Kriz     Consumer   46  United States
# AG-10270        Alejandro Grove     Consumer   18  United States
# ZD-21925     Zuschuss Donatelli     Consumer   66  United States
#
#                         City           State  Postal Code   Region
# Customer ID
# CG-12520           Henderson        Kentucky        42420    South
# DV-13045         Los Angeles      California        90036     West
# ...

# %%
Pcustomer = pd.DataFrame ([
    {
     'Customer ID' : 'CG-12520',
     'Customer Name' :'Claire Gute',
     'Segment ' : 'Consumer',
     'Age' : 67,
     'Country' : 'United States',
     'City' : 'Henderson',
     'State' : 'Kentucky',
     'Postal Code' : 424200,
     'Region' : 'South'
    },
    {
     'Customer ID' : 'DV-13045',
     'Customer Name' :'Darrin Van Huff',
     'Segment ' : 'Corporate',
     'Age' : 31,
     'Country' : 'United States',
     'City' : 'Los Angeles',
     'State' : 'California',
     'Postal Code' : 90036,
     'Region' : 'West'
    },
    {
     'Customer ID' : 'SO-20335',
     'Customer Name' :" Sean O'Donnell ",
     'Segment ' : 'Consumer',
     'Age' : 65,
     'Country' : 'United States',
     'City' : 'Fort Lauderdale',
     'State' : 'Florida',
     'Postal Code' : 33311,
     'Region' : 'South'
    },
    {
     'Customer ID' : 'BH-11710',
     'Customer Name' :'Brosina Hoffman',
     'Segment ' : 'Consumer',
     'Age' : 20,
     'Country' : 'United States',
     'City' : 'Los Angeles',
     'State' : 'California',
     'Postal Code' : 90032,
     'Region' : 'West'
    },
    {
     'Customer ID' : 'AA-10480',
     'Customer Name' :'Andrew Allen',
     'Segment ' : 'Consumer',
     'Age' : 50,
     'Country' : 'United States',
     'City' : 'Concord',
     'State' : 'North Carolina',
     'Postal Code' : 28027,
     'Region' : 'South'
    },
    {
     'Customer ID' : 'IM-15070',
     'Customer Name' :'Irene Maddox',
     'Segment ' : 'Consumer',
     'Age' : 66,
     'Country' : 'United States',
     'City' : 'Seattle',
     'State' : 'KenWashingtontucky',
     'Postal Code' : 98103,
     'Region' : 'West'
    },
    {
     'Customer ID' : 'HP-14815',
     'Customer Name' :'Harold Pawlan',
     'Segment ' : 'Home Office',
     'Age' : 20,
     'Country' : 'United States',
     'City' : 'Fort Worth',
     'State' : 'Texas',
     'Postal Code' : 76106,
     'Region' : 'Central'
    },
    {
     'Customer ID' : 'PK-19075',
     'Customer Name' :'Pete Kriz',
     'Segment ' : 'Consumer',
     'Age' : 46,
     'Country' : 'United States',
     'City' : 'Madison',
     'State' : 'Wisconsin',
     'Postal Code' : 53711,
     'Region' : 'Central'
    },
    {
     'Customer ID' : 'AG-10270',
     'Customer Name' :'Alejandro Grove',
     'Segment ' : 'Consumer',
     'Age' : 18,
     'Country' : 'United States',
     'City' : 'West Jordan',
     'State' : 'West Jordan',
     'Postal Code' : 84084,
     'Region' : 'West'
    },
    {
     'Customer ID' : 'ZD-21925',
     'Customer Name' :'Zuschuss Donatelli',
     'Segment ' : 'Consumer',
     'Age' : 66,
     'Country' : 'United States',
     'City' : 'San Francisco',
     'State' : 'California',
     'Postal Code' : 94109,
     'Region' : 'West'
    },
    
])

# %%
Pcustomer
# Out:
#   Customer ID       Customer Name     Segment   Age        Country  \
# 0    CG-12520         Claire Gute     Consumer   67  United States
# 1    DV-13045     Darrin Van Huff    Corporate   31  United States
# 2    SO-20335     Sean O'Donnell      Consumer   65  United States
# 3    BH-11710     Brosina Hoffman     Consumer   20  United States
# 4    AA-10480        Andrew Allen     Consumer   50  United States
# 5    IM-15070        Irene Maddox     Consumer   66  United States
# 6    HP-14815       Harold Pawlan  Home Office   20  United States
# 7    PK-19075           Pete Kriz     Consumer   46  United States
# 8    AG-10270     Alejandro Grove     Consumer   18  United States
# 9    ZD-21925  Zuschuss Donatelli     Consumer   66  United States
#
#               City               State  Postal Code   Region
# 0        Henderson            Kentucky       424200    South
# 1      Los Angeles          California        90036     West
# ...

# %%
Pcustomer.to_csv('Pcustomer.csv', index = 0)

# %%
product = pd.read_csv('E:/Data Analytics/Python/python practice/pandas/pandas practice/product.csv',index_col=0,header=0)

# %%
product
# Out:
#                         category sub_category  \
# product_id
# FUR-BO-10001798        Furniture    Bookcases
# FUR-CH-10000454        Furniture       Chairs
# OFF-LA-10000240  Office Supplies       Labels
# FUR-TA-10000577        Furniture       Tables
# OFF-ST-10000760  Office Supplies      Storage
# ...                          ...          ...
# TEC-PH-10002817       Technology       Phones
# TEC-MA-10003589       Technology     Machines
# OFF-AP-10003099  Office Supplies   Appliances
# TEC-PH-10002645       Technology       Phones
# OFF-ST-10001627  Office Supplies      Storage
#
#                                                       product_name
# product_id
# FUR-BO-10001798                  Bush Somerset Collection Bookcase
# FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs ...
# OFF-LA-10000240  Self-Adhesive Address Labels for Typewriters b...
# FUR-TA-10000577      Bretford CR4500 Series Slim Rectangular Table
# ...

# %%
product.iloc[0:10]
# Out:
#                         category sub_category  \
# product_id
# FUR-BO-10001798        Furniture    Bookcases
# FUR-CH-10000454        Furniture       Chairs
# OFF-LA-10000240  Office Supplies       Labels
# FUR-TA-10000577        Furniture       Tables
# OFF-ST-10000760  Office Supplies      Storage
# FUR-FU-10001487        Furniture  Furnishings
# OFF-AR-10002833  Office Supplies          Art
# TEC-PH-10002275       Technology       Phones
# OFF-BI-10003910  Office Supplies      Binders
# OFF-AP-10002892  Office Supplies   Appliances
#
#                                                       product_name
# product_id
# FUR-BO-10001798                  Bush Somerset Collection Bookcase
# FUR-CH-10000454  Hon Deluxe Fabric Upholstered Stacking Chairs ...
# OFF-LA-10000240  Self-Adhesive Address Labels for Typewriters b...
# FUR-TA-10000577      Bretford CR4500 Series Slim Rectangular Table
# OFF-ST-10000760                      Eldon Fold N Roll Cart System
# ...

# %%
Pproduct = pd.DataFrame([
    {
        'product_id': 'FUR-BO-10001798',
        'category': 'Furniture',
        'sub_category':'Bookcases',
       'product_name' : 'Bush Somerset Collection Bookcase'
    },
    {
        'product_id': 'FUR-CH-10000454',
        'category': 'Furniture',
        'sub_category':'Chairs',
       'product_name' : 'Hon Deluxe Fabric Upholstered Stacking Chairs ...'
    },
    {
        'product_id': 'OFF-LA-10000240',
        'category': 'Office Supplies',
        'sub_category':'Labels',
       'product_name' : 'Self-Adhesive Address Labels for Typewriters b...'
    },
    {
        'product_id': 'FUR-TA-10000577',
        'category': 'Tables',
        'sub_category':'Bookcases',
       'product_name' : 'Bretford CR4500 Series Slim Rectangular Table'
    },
    {
        'product_id': 'OFF-ST-10000760',
        'category': 'Office Suppliese',
        'sub_category':'Storage',
       'product_name' : 'Eldon Fold N Roll Cart System'
    },
    {
        'product_id': 'FUR-FU-10001487',
        'category': 'Furniture',
        'sub_category':'Furnishings',
       'product_name' : 'Eldon Expressions Wood and Plastic Desk Access...'
    },
    {
        'product_id': 'OFF-AR-10002833',
        'category': 'Office Supplies',
        'sub_category':'Art',
       'product_name' : 'Newell 322'
    },
    {
        'product_id': 'TEC-PH-10002275',
        'category': 'Technology',
        'sub_category':'Phones',
       'product_name' : 'Mitel 5320 IP Phone VoIP phone'
    },
    {
        'product_id': 'OFF-BI-10003910',
        'category': 'Office Supplies',
        'sub_category':'Binders',
       'product_name' : 'DXL Angle-View Binders with Locking Rings by S...'
    },
    {
        'product_id': 'OFF-AP-10002892',
        'category': 'Office Supplies',
        'sub_category':'Appliances',
       'product_name' : 'Belkin F5C206VTEL 6 Outlet Surge'
    }
])

# %%
Pproduct
# Out:
#         product_id          category sub_category  \
# 0  FUR-BO-10001798         Furniture    Bookcases
# 1  FUR-CH-10000454         Furniture       Chairs
# 2  OFF-LA-10000240   Office Supplies       Labels
# 3  FUR-TA-10000577            Tables    Bookcases
# 4  OFF-ST-10000760  Office Suppliese      Storage
# 5  FUR-FU-10001487         Furniture  Furnishings
# 6  OFF-AR-10002833   Office Supplies          Art
# 7  TEC-PH-10002275        Technology       Phones
# 8  OFF-BI-10003910   Office Supplies      Binders
# 9  OFF-AP-10002892   Office Supplies   Appliances
#
#                                         product_name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs ...
# 2  Self-Adhesive Address Labels for Typewriters b...
# 3      Bretford CR4500 Series Slim Rectangular Table
# 4                      Eldon Fold N Roll Cart System
# 5  Eldon Expressions Wood and Plastic Desk Access...
# ...

# %%
Pproduct.to_csv('pproduct.csv', index=0)
